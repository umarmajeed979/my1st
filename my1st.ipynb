# %%
import matplotlib.pyplot as plt

porosity=[0.37586413,0.30673585,0.24561348,0.19751556,0.14655910]
per=[4018.77,3866.78,2804.03,1809.18,918.56]

plt.plot(porosity,per , color='indigo', marker='*')
plt.xlabel('porosity')
plt.ylabel('permaebility')
plt.title('Graph b/w porosity and permaebility')
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
